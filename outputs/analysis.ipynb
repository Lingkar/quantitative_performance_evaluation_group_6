# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
df = pd.read_table('raw_results.txt', sep='\t').drop(columns='rep')

# %%
df
# Out:
#      le  noise  ks1  ks2  epochs     acc
# 0     0      0    3    3       5  0.9081
# 1     0      0    3    3      10  0.9279
# 2     0      0    3    3      20  0.9445
# 3     0      0    3    8       5  0.9205
# 4     0      0    3    8      10  0.9428
# ..   ..    ...  ...  ...     ...     ...
# 103  40     40    8    3      10  0.9086
# 104  40     40    8    3      20  0.9261
# 105  40     40    8    8       5  0.8713
# 106  40     40    8    8      10  0.9149
# 107  40     40    8    8      20  0.9309
#
# [108 rows x 6 columns]

# %%
model_string = "acc ~ "+"".join(["C(%s)*"%i if i !='acc' else '' for i in df.columns])[:-1]

# %%
model = ols("acc ~ C(le)*C(noise)*C(ks1)*C(ks2)", data=df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    acc   R-squared:                       0.363
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     1.173
# Date:                Fri, 23 Oct 2020   Prob (F-statistic):              0.280
# Time:                        16:39:16   Log-Likelihood:                 279.37
# No. Observations:                 108   AIC:                            -486.7
# Df Residuals:                      72   BIC:                            -390.2
# Df Model:                          35
# Covariance Type:            nonrobust
# ...
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# ...

# %%
sm.stats.anova_lm(model, typ=2)
# Out:
# C:\Users\bzi\Miniconda3\envs\myenv\lib\site-packages\statsmodels\regression\linear_model.py:1620: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-f58ab3e18fc7> in <module>
# ----> 1 sm.stats.anova_lm(model, typ=2)
#
# ~\Miniconda3\envs\myenv\lib\site-packages\statsmodels\stats\anova.py in anova_lm(*args, **kwargs)
#     347     if len(args) == 1:
#     348         model = args[0]
# --> 349         return anova_single(model, **kwargs)
#     350
#     351     if typ not in [1, "I"]:
#
# ~\Miniconda3\envs\myenv\lib\site-packages\statsmodels\stats\anova.py in anova_single(model, **kwargs)
#      78                                 n_rows, test, pr_test, robust)
#      79     elif typ in [2, "II"]:
# ...

# %%
np.any(df.isna())
# Out:
# False

# %%
model_string
# Out:
# 'acc ~ C(le)*C(noise)*C(ks1)*C(ks2)'
