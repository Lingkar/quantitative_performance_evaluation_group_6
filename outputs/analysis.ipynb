# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
df = pd.read_table('raw_results.txt', sep='\t').drop(columns='rep')

# %%
df.columns[-1]
# Out:
# 'acc'

# %% [markdown]
# ### Fit linear model on full interactions
# Assuming that the response variable is represented by the rightmost column

# %%
model_string = "%s ~ "%df.columns[-1]+"".join(["C(%s)*"%i if i != df.columns[-1] else '' for i in df.columns])[:-1]
model_string
# Out:
# 'acc ~ C(le)*C(noise)*C(ks1)*C(ks2)*C(epochs)'

# %%
model = ols(model_string, data=df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    acc   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     47.54
# Date:                Sat, 24 Oct 2020   Prob (F-statistic):          1.47e-149
# Time:                        12:19:43   Log-Likelihood:                 1618.0
# No. Observations:                 432   AIC:                            -3020.
# Df Residuals:                     324   BIC:                            -2581.
# Df Model:                         107
# Covariance Type:            nonrobust
# ======================================================================================================================================
#                                                                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                              0.9134      0.003    276.701      0.000       0.907       0.920
# C(le)[T.20]                                                           -0.0187      0.005     -4.000      0.000      -0.028      -0.009
# C(le)[T.40]                                                           -0.0318      0.005     -6.817      0.000      -0.041      -0.023
# C(noise)[T.20]                                                        -0.0113      0.005     -2.415      0.016      -0.020      -0.002
# C(noise)[T.40]                                                        -0.0144      0.005     -3.085      0.002      -0.024      -0.005
# C(ks1)[T.8]                                                            0.0093      0.005      1.998      0.047       0.000       0.019
# C(ks2)[T.8]                                                            0.0041      0.005      0.884      0.378      -0.005       0.013
# C(epochs)[T.10]                                                        0.0220      0.005      4.702      0.000       0.013       0.031
# C(epochs)[T.20]                                                        0.0384      0.005      8.231      0.000       0.029       0.048
# C(le)[T.20]:C(noise)[T.20]                                             0.0106      0.007      1.602      0.110      -0.002       0.024
# C(le)[T.40]:C(noise)[T.20]                                             0.0011      0.007      0.167      0.868      -0.012       0.014
# C(le)[T.20]:C(noise)[T.40]                                             0.0119      0.007      1.803      0.072      -0.001       0.025
# C(le)[T.40]:C(noise)[T.40]                                           -7.5e-05      0.007     -0.011      0.991      -0.013       0.013
# C(le)[T.20]:C(ks1)[T.8]                                                0.0077      0.007      1.174      0.241      -0.005       0.021
# C(le)[T.40]:C(ks1)[T.8]                                               -0.0011      0.007     -0.159      0.874      -0.014       0.012
# C(noise)[T.20]:C(ks1)[T.8]                                             0.0030      0.007      0.462      0.644      -0.010       0.016
# C(noise)[T.40]:C(ks1)[T.8]                                             0.0007      0.007      0.102      0.919      -0.012       0.014
# C(le)[T.20]:C(ks2)[T.8]                                                0.0133      0.007      2.018      0.044       0.000       0.026
# C(le)[T.40]:C(ks2)[T.8]                                                0.0161      0.007      2.439      0.015       0.003       0.029
# C(noise)[T.20]:C(ks2)[T.8]                                             0.0056      0.007      0.852      0.395      -0.007       0.019
# C(noise)[T.40]:C(ks2)[T.8]                                             0.0005      0.007      0.076      0.940      -0.012       0.013
# C(ks1)[T.8]:C(ks2)[T.8]                                                0.0050      0.007      0.765      0.445      -0.008       0.018
# C(le)[T.20]:C(epochs)[T.10]                                            0.0034      0.007      0.511      0.610      -0.010       0.016
# C(le)[T.40]:C(epochs)[T.10]                                            0.0072      0.007      1.091      0.276      -0.006       0.020
# C(le)[T.20]:C(epochs)[T.20]                                            0.0091      0.007      1.378      0.169      -0.004       0.022
# C(le)[T.40]:C(epochs)[T.20]                                            0.0124      0.007      1.882      0.061      -0.001       0.025
# C(noise)[T.20]:C(epochs)[T.10]                                         0.0024      0.007      0.360      0.719      -0.011       0.015
# C(noise)[T.40]:C(epochs)[T.10]                                         0.0026      0.007      0.390      0.697      -0.010       0.016
# C(noise)[T.20]:C(epochs)[T.20]                                         0.0055      0.007      0.833      0.405      -0.007       0.018
# C(noise)[T.40]:C(epochs)[T.20]                                         0.0044      0.007      0.666      0.506      -0.009       0.017
# C(ks1)[T.8]:C(epochs)[T.10]                                           -0.0013      0.007     -0.197      0.844      -0.014       0.012
# C(ks1)[T.8]:C(epochs)[T.20]                                           -0.0020      0.007     -0.307      0.759      -0.015       0.011
# C(ks2)[T.8]:C(epochs)[T.10]                                            0.0008      0.007      0.121      0.904      -0.012       0.014
# C(ks2)[T.8]:C(epochs)[T.20]                                            0.0007      0.007      0.110      0.913      -0.012       0.014
# C(le)[T.20]:C(noise)[T.20]:C(ks1)[T.8]                                -0.0120      0.009     -1.288      0.199      -0.030       0.006
# C(le)[T.40]:C(noise)[T.20]:C(ks1)[T.8]                                 0.0019      0.009      0.201      0.841      -0.016       0.020
# C(le)[T.20]:C(noise)[T.40]:C(ks1)[T.8]                                -0.0103      0.009     -1.106      0.270      -0.029       0.008
# C(le)[T.40]:C(noise)[T.40]:C(ks1)[T.8]                                -0.0004      0.009     -0.040      0.968      -0.019       0.018
# C(le)[T.20]:C(noise)[T.20]:C(ks2)[T.8]                                -0.0178      0.009     -1.912      0.057      -0.036       0.001
# C(le)[T.40]:C(noise)[T.20]:C(ks2)[T.8]                                -0.0179      0.009     -1.915      0.056      -0.036       0.000
# C(le)[T.20]:C(noise)[T.40]:C(ks2)[T.8]                                -0.0199      0.009     -2.129      0.034      -0.038      -0.002
# C(le)[T.40]:C(noise)[T.40]:C(ks2)[T.8]                                -0.0181      0.009     -1.941      0.053      -0.036       0.000
# C(le)[T.20]:C(ks1)[T.8]:C(ks2)[T.8]                                   -0.0169      0.009     -1.810      0.071      -0.035       0.001
# C(le)[T.40]:C(ks1)[T.8]:C(ks2)[T.8]                                   -0.0213      0.009     -2.281      0.023      -0.040      -0.003
# C(noise)[T.20]:C(ks1)[T.8]:C(ks2)[T.8]                                -0.0075      0.009     -0.806      0.421      -0.026       0.011
# C(noise)[T.40]:C(ks1)[T.8]:C(ks2)[T.8]                                -0.0054      0.009     -0.576      0.565      -0.024       0.013
# C(le)[T.20]:C(noise)[T.20]:C(epochs)[T.10]                            -0.0030      0.009     -0.319      0.750      -0.021       0.015
# C(le)[T.40]:C(noise)[T.20]:C(epochs)[T.10]                            -0.0054      0.009     -0.581      0.562      -0.024       0.013
# C(le)[T.20]:C(noise)[T.40]:C(epochs)[T.10]                            -0.0036      0.009     -0.380      0.704      -0.022       0.015
# C(le)[T.40]:C(noise)[T.40]:C(epochs)[T.10]                            -0.0041      0.009     -0.444      0.657      -0.023       0.014
# C(le)[T.20]:C(noise)[T.20]:C(epochs)[T.20]                            -0.0082      0.009     -0.878      0.380      -0.027       0.010
# C(le)[T.40]:C(noise)[T.20]:C(epochs)[T.20]                            -0.0091      0.009     -0.980      0.328      -0.028       0.009
# C(le)[T.20]:C(noise)[T.40]:C(epochs)[T.20]                            -0.0095      0.009     -1.012      0.312      -0.028       0.009
# C(le)[T.40]:C(noise)[T.40]:C(epochs)[T.20]                            -0.0041      0.009     -0.444      0.657      -0.023       0.014
# C(le)[T.20]:C(ks1)[T.8]:C(epochs)[T.10]                               -0.0013      0.009     -0.139      0.889      -0.020       0.017
# C(le)[T.40]:C(ks1)[T.8]:C(epochs)[T.10]                               -0.0031      0.009     -0.332      0.740      -0.021       0.015
# C(le)[T.20]:C(ks1)[T.8]:C(epochs)[T.20]                               -0.0045      0.009     -0.487      0.626      -0.023       0.014
# C(le)[T.40]:C(ks1)[T.8]:C(epochs)[T.20]                               -0.0048      0.009     -0.511      0.609      -0.023       0.014
# C(noise)[T.20]:C(ks1)[T.8]:C(epochs)[T.10]                            -0.0005      0.009     -0.056      0.955      -0.019       0.018
# C(noise)[T.40]:C(ks1)[T.8]:C(epochs)[T.10]                             0.0005      0.009      0.054      0.957      -0.018       0.019
# C(noise)[T.20]:C(ks1)[T.8]:C(epochs)[T.20]                            -0.0027      0.009     -0.287      0.775      -0.021       0.016
# C(noise)[T.40]:C(ks1)[T.8]:C(epochs)[T.20]                            -0.0004      0.009     -0.043      0.966      -0.019       0.018
# C(le)[T.20]:C(ks2)[T.8]:C(epochs)[T.10]                               -0.0037      0.009     -0.396      0.692      -0.022       0.015
# C(le)[T.40]:C(ks2)[T.8]:C(epochs)[T.10]                               -0.0068      0.009     -0.726      0.469      -0.025       0.012
# C(le)[T.20]:C(ks2)[T.8]:C(epochs)[T.20]                               -0.0110      0.009     -1.181      0.239      -0.029       0.007
# C(le)[T.40]:C(ks2)[T.8]:C(epochs)[T.20]                               -0.0144      0.009     -1.548      0.123      -0.033       0.004
# C(noise)[T.20]:C(ks2)[T.8]:C(epochs)[T.10]                            -0.0005      0.009     -0.056      0.955      -0.019       0.018
# C(noise)[T.40]:C(ks2)[T.8]:C(epochs)[T.10]                             0.0008      0.009      0.086      0.932      -0.018       0.019
# C(noise)[T.20]:C(ks2)[T.8]:C(epochs)[T.20]                            -0.0033      0.009     -0.359      0.720      -0.022       0.015
# C(noise)[T.40]:C(ks2)[T.8]:C(epochs)[T.20]                             0.0004      0.009      0.043      0.966      -0.018       0.019
# C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.10]                               -0.0009      0.009     -0.096      0.923      -0.019       0.017
# C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.20]                               -0.0053      0.009     -0.568      0.571      -0.024       0.013
# C(le)[T.20]:C(noise)[T.20]:C(ks1)[T.8]:C(ks2)[T.8]                     0.0178      0.013      1.346      0.179      -0.008       0.044
# C(le)[T.40]:C(noise)[T.20]:C(ks1)[T.8]:C(ks2)[T.8]                     0.0134      0.013      1.019      0.309      -0.013       0.039
# C(le)[T.20]:C(noise)[T.40]:C(ks1)[T.8]:C(ks2)[T.8]                     0.0194      0.013      1.467      0.143      -0.007       0.045
# C(le)[T.40]:C(noise)[T.40]:C(ks1)[T.8]:C(ks2)[T.8]                     0.0179      0.013      1.356      0.176      -0.008       0.044
# C(le)[T.20]:C(noise)[T.20]:C(ks1)[T.8]:C(epochs)[T.10]                 0.0020      0.013      0.153      0.878      -0.024       0.028
# C(le)[T.40]:C(noise)[T.20]:C(ks1)[T.8]:C(epochs)[T.10]                 0.0050      0.013      0.381      0.704      -0.021       0.031
# C(le)[T.20]:C(noise)[T.40]:C(ks1)[T.8]:C(epochs)[T.10]                 0.0012      0.013      0.089      0.929      -0.025       0.027
# C(le)[T.40]:C(noise)[T.40]:C(ks1)[T.8]:C(epochs)[T.10]                 0.0013      0.013      0.102      0.919      -0.025       0.027
# C(le)[T.20]:C(noise)[T.20]:C(ks1)[T.8]:C(epochs)[T.20]                 0.0049      0.013      0.373      0.709      -0.021       0.031
# C(le)[T.40]:C(noise)[T.20]:C(ks1)[T.8]:C(epochs)[T.20]                 0.0076      0.013      0.579      0.563      -0.018       0.034
# C(le)[T.20]:C(noise)[T.40]:C(ks1)[T.8]:C(epochs)[T.20]                 0.0077      0.013      0.583      0.560      -0.018       0.034
# C(le)[T.40]:C(noise)[T.40]:C(ks1)[T.8]:C(epochs)[T.20]                -0.0005      0.013     -0.036      0.971      -0.026       0.026
# C(le)[T.20]:C(noise)[T.20]:C(ks2)[T.8]:C(epochs)[T.10]                 0.0015      0.013      0.112      0.911      -0.025       0.027
# C(le)[T.40]:C(noise)[T.20]:C(ks2)[T.8]:C(epochs)[T.10]                 0.0061      0.013      0.462      0.644      -0.020       0.032
# C(le)[T.20]:C(noise)[T.40]:C(ks2)[T.8]:C(epochs)[T.10]                 0.0038      0.013      0.288      0.774      -0.022       0.030
# C(le)[T.40]:C(noise)[T.40]:C(ks2)[T.8]:C(epochs)[T.10]                 0.0111      0.013      0.843      0.400      -0.015       0.037
# C(le)[T.20]:C(noise)[T.20]:C(ks2)[T.8]:C(epochs)[T.20]                 0.0084      0.013      0.636      0.525      -0.018       0.034
# C(le)[T.40]:C(noise)[T.20]:C(ks2)[T.8]:C(epochs)[T.20]                 0.0132      0.013      1.003      0.316      -0.013       0.039
# C(le)[T.20]:C(noise)[T.40]:C(ks2)[T.8]:C(epochs)[T.20]                 0.0094      0.013      0.710      0.478      -0.017       0.035
# C(le)[T.40]:C(noise)[T.40]:C(ks2)[T.8]:C(epochs)[T.20]                 0.0166      0.013      1.255      0.210      -0.009       0.043
# C(le)[T.20]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.10]                    0.0046      0.013      0.348      0.728      -0.021       0.031
# C(le)[T.40]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.10]                    0.0149      0.013      1.127      0.261      -0.011       0.041
# C(le)[T.20]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.20]                    0.0118      0.013      0.892      0.373      -0.014       0.038
# C(le)[T.40]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.20]                    0.0270      0.013      2.049      0.041       0.001       0.053
# C(noise)[T.20]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.10]                 0.0002      0.013      0.019      0.985      -0.026       0.026
# C(noise)[T.40]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.10]                 0.0028      0.013      0.208      0.835      -0.023       0.029
# C(noise)[T.20]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.20]                 0.0045      0.013      0.343      0.732      -0.021       0.031
# C(noise)[T.40]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.20]                 0.0068      0.013      0.519      0.604      -0.019       0.033
# C(le)[T.20]:C(noise)[T.20]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.10]     0.0007      0.019      0.037      0.970      -0.036       0.037
# C(le)[T.40]:C(noise)[T.20]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.10]    -0.0088      0.019     -0.469      0.640      -0.045       0.028
# C(le)[T.20]:C(noise)[T.40]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.10]    -0.0080      0.019     -0.430      0.668      -0.045       0.029
# C(le)[T.40]:C(noise)[T.40]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.10]    -0.0124      0.019     -0.665      0.506      -0.049       0.024
# C(le)[T.20]:C(noise)[T.20]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.20]    -0.0026      0.019     -0.142      0.887      -0.039       0.034
# C(le)[T.40]:C(noise)[T.20]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.20]    -0.0187      0.019     -1.001      0.317      -0.055       0.018
# C(le)[T.20]:C(noise)[T.40]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.20]    -0.0173      0.019     -0.929      0.354      -0.054       0.019
# C(le)[T.40]:C(noise)[T.40]:C(ks1)[T.8]:C(ks2)[T.8]:C(epochs)[T.20]    -0.0231      0.019     -1.240      0.216      -0.060       0.014
# ==============================================================================
# Omnibus:                      108.767   Durbin-Watson:                   0.743
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              979.263
# Skew:                           0.792   Prob(JB):                    2.27e-213
# Kurtosis:                      10.204   Cond. No.                         356.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sm.stats.anova_lm(model, typ=3)
# Out:
#                                               sum_sq     df             F  \
# Intercept                               3.337016e+00    1.0  76563.245706
# C(le)                                   2.046012e-03    2.0     23.471466
# C(noise)                                4.590017e-04    2.0      5.265582
# C(ks1)                                  1.739112e-04    1.0      3.990155
# C(ks2)                                  3.403125e-05    1.0      0.780800
# C(epochs)                               2.972945e-03    2.0     34.105073
# C(le):C(noise)                          2.209861e-04    4.0      1.267556
# C(le):C(ks1)                            9.240333e-05    2.0      1.060034
# C(noise):C(ks1)                         1.026583e-05    2.0      0.117768
# C(le):C(ks2)                            2.963108e-04    2.0      3.399223
# C(noise):C(ks2)                         3.877083e-05    2.0      0.444772
# C(ks1):C(ks2)                           2.550250e-05    1.0      0.585120
# C(le):C(epochs)                         1.717483e-04    4.0      0.985132
# C(noise):C(epochs)                      3.463000e-05    4.0      0.198634
# C(ks1):C(epochs)                        4.210833e-06    2.0      0.048306
# C(ks2):C(epochs)                        7.808333e-07    2.0      0.008958
# C(le):C(noise):C(ks1)                   1.268067e-04    4.0      0.727351
# C(le):C(noise):C(ks2)                   3.048992e-04    4.0      1.748873
# C(le):C(ks1):C(ks2)                     2.528867e-04    2.0      2.901069
# C(noise):C(ks1):C(ks2)                  3.004625e-05    2.0      0.344685
# C(le):C(noise):C(epochs)                8.573185e-05    8.0      0.245875
# C(le):C(ks1):C(epochs)                  1.643167e-05    4.0      0.094251
# C(noise):C(ks1):C(epochs)               4.680556e-06    4.0      0.026847
# C(le):C(ks2):C(epochs)                  1.164031e-04    4.0      0.667677
# C(noise):C(ks2):C(epochs)               9.363889e-06    4.0      0.053710
# C(ks1):C(ks2):C(epochs)                 1.608667e-05    2.0      0.184543
# C(le):C(noise):C(ks1):C(ks2)            1.382244e-04    4.0      0.792843
# C(le):C(noise):C(ks1):C(epochs)         5.200176e-05    8.0      0.149139
# C(le):C(noise):C(ks2):C(epochs)         8.570231e-05    8.0      0.245790
# C(le):C(ks1):C(ks2):C(epochs)           1.862657e-04    4.0      1.068403
# C(noise):C(ks1):C(ks2):C(epochs)        1.353278e-05    4.0      0.077623
# C(le):C(noise):C(ks1):C(ks2):C(epochs)  1.024649e-04    8.0      0.293865
# Residual                                1.412157e-02  324.0           NaN
#
#                                               PR(>F)
# Intercept                               0.000000e+00
# C(le)                                   3.023719e-10
# C(noise)                                5.617790e-03
# C(ks1)                                  4.660267e-02
# C(ks2)                                  3.775517e-01
# C(epochs)                               3.616114e-14
# C(le):C(noise)                          2.825651e-01
# C(le):C(ks1)                            3.476424e-01
# C(noise):C(ks1)                         8.889405e-01
# C(le):C(ks2)                            3.459482e-02
# C(noise):C(ks2)                         6.413613e-01
# C(ks1):C(ks2)                           4.448692e-01
# C(le):C(epochs)                         4.157250e-01
# C(noise):C(epochs)                      9.389821e-01
# C(ks1):C(epochs)                        9.528491e-01
# C(ks2):C(epochs)                        9.910827e-01
# C(le):C(noise):C(ks1)                   5.737896e-01
# C(le):C(noise):C(ks2)                   1.389672e-01
# C(le):C(ks1):C(ks2)                     5.639364e-02
# C(noise):C(ks1):C(ks2)                  7.087029e-01
# C(le):C(noise):C(epochs)                9.816442e-01
# C(le):C(ks1):C(epochs)                  9.842425e-01
# C(noise):C(ks1):C(epochs)               9.986011e-01
# C(le):C(ks2):C(epochs)                  6.148341e-01
# C(noise):C(ks2):C(epochs)               9.945989e-01
# C(ks1):C(ks2):C(epochs)                 8.315713e-01
# C(le):C(noise):C(ks1):C(ks2)            5.304940e-01
# C(le):C(noise):C(ks1):C(epochs)         9.966230e-01
# C(le):C(noise):C(ks2):C(epochs)         9.816646e-01
# C(le):C(ks1):C(ks2):C(epochs)           3.721201e-01
# C(noise):C(ks1):C(ks2):C(epochs)        9.890732e-01
# C(le):C(noise):C(ks1):C(ks2):C(epochs)  9.677693e-01
# Residual                                         NaN

# %%
df.corr()
# Out:
#               le     noise       ks1       ks2    epochs       acc
# le      1.000000  0.000000  0.000000  0.000000  0.000000 -0.492076
# noise   0.000000  1.000000  0.000000  0.000000  0.000000 -0.246912
# ks1     0.000000  0.000000  1.000000  0.000000  0.000000  0.165608
# ks2     0.000000  0.000000  0.000000  1.000000  0.000000  0.122866
# epochs  0.000000  0.000000  0.000000  0.000000  1.000000  0.721321
# acc    -0.492076 -0.246912  0.165608  0.122866  0.721321  1.000000
