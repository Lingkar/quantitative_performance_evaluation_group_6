# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
import researchpy as rp

# %%
df = pd.read_table('raw_results.txt', sep='\t').drop(columns='rep')
pd.set_option('display.max_rows', df.shape[0]+1)

# %%
rptab = rp.summary_cont(df.groupby(['le', 'noise', 'ks1', 'ks2', 'epochs']))['acc']
rptab.reset_index()
# Out:
#      le  noise  ks1  ks2  epochs  N    Mean      SD      SE  95% Conf.  \
# 0     0      0    3    3       5  5  0.9089  0.0135  0.0060     0.8921
# 1     0      0    3    3      10  5  0.9310  0.0129  0.0058     0.9150
# 2     0      0    3    3      20  5  0.9482  0.0102  0.0046     0.9356
# 3     0      0    3    8       5  5  0.9195  0.0068  0.0030     0.9110
# 4     0      0    3    8      10  5  0.9417  0.0053  0.0024     0.9351
# 5     0      0    3    8      20  5  0.9571  0.0029  0.0013     0.9534
# 6     0      0    8    3       5  5  0.9227  0.0071  0.0032     0.9139
# 7     0      0    8    3      10  5  0.9430  0.0050  0.0022     0.9368
# 8     0      0    8    3      20  5  0.9582  0.0033  0.0015     0.9541
# 9     0      0    8    8       5  5  0.9331  0.0055  0.0025     0.9263
# 10    0      0    8    8      10  5  0.9539  0.0044  0.0020     0.9484
# 11    0      0    8    8      20  5  0.9651  0.0036  0.0016     0.9606
# ...

# %% [markdown]
# ### Fit linear model on full interactions
# Assuming that the response variable is represented by the rightmost column

# %%
model_string = "%s ~ "%df.columns[-1]+"".join(["C(%s)*"%i if i != df.columns[-1] else '' for i in df.columns])[:-1]
model_string
# Out:
# 'acc ~ C(le)*C(noise)*C(ks1)*C(ks2)*C(epochs)'

# %%
model = ols(model_string, data=df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    acc   R-squared:                       0.939
# Model:                            OLS   Adj. R-squared:                  0.924
# Method:                 Least Squares   F-statistic:                     62.01
# Date:                Sat, 24 Oct 2020   Prob (F-statistic):          6.45e-208
# Time:                        17:22:35   Log-Likelihood:                 2012.6
# No. Observations:                 540   AIC:                            -3809.
# Df Residuals:                     432   BIC:                            -3346.
# Df Model:                         107
# Covariance Type:            nonrobust
# ...
#                                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
sm.stats.anova_lm(model, typ=2)
# Out:
#                                           sum_sq     df            F  \
# C(le)                                   0.074851    2.0   882.927717
# C(noise)                                0.019770    2.0   233.206910
# C(ks1)                                  0.009085    1.0   214.325917
# C(ks2)                                  0.005594    1.0   131.982383
# C(epochs)                               0.166146    2.0  1959.834727
# C(le):C(noise)                          0.000860    4.0     5.073484
# C(le):C(ks1)                            0.000197    2.0     2.323573
# C(noise):C(ks1)                         0.000194    2.0     2.289518
# C(le):C(ks2)                            0.000364    2.0     4.298849
# C(noise):C(ks2)                         0.000965    2.0    11.381661
# C(ks1):C(ks2)                           0.000084    1.0     1.980240
# C(le):C(epochs)                         0.001064    4.0     6.274304
# C(noise):C(epochs)                      0.000216    4.0     1.274326
# ...

# %% [markdown]
# ### group results and print top $30$ best and worst accuracies

# %%
dfgroup = df.groupby(list(df.columns.values[:-1])).mean().reset_index()
dfgroup = dfgroup.rename(columns={"le": "Label Error", "noise": "Image Noise", "ks1": "Kernel Size 1", "ks2": "Kernel Size 2","acc": "Accuracy"})

# %%
nlargest = dfgroup.nlargest(30,'Accuracy').reset_index().drop(columns=['index'])
print(nlargest.to_string(index=False))
nsmallest = dfgroup.nlargest(30,'Accuracy').reset_index().drop(columns=['index'])
print(nsmallest.to_string(index=False))
# Out:
#  Label Error  Image Noise  Kernel Size 1  Kernel Size 2  epochs  Accuracy
#            0            0              8              8      20   0.96512
#            0           20              8              8      20   0.95864
#            0            0              8              3      20   0.95818
#            0            0              3              8      20   0.95708
#            0           40              8              8      20   0.95610
#           20            0              8              8      20   0.95610
#            0           20              8              3      20   0.95414
#            0            0              8              8      10   0.95392
#            0           20              3              8      20   0.95384
#           20            0              8              3      20   0.95316
#           20            0              3              8      20   0.94954
#            0           40              8              3      20   0.94928
# ...

# %% [markdown]
# ### Make correlation plots

# %%
sns.set()
for cat in dfgroup.columns[:-2]:
    sns.catplot(data=dfgroup, x=cat, y="Accuracy", hue="epochs")
